# %%
# Use the file spotify.csv
# 1. Convert this file into a pandas Data Frame. (0.5 marks)
# 2. Display basic informa􀆟on like memory and data types for this data frame.
# (0.5 marks)
# 3. Display basic sta􀆟s􀆟cs like mean, std, quar􀆟les, etc. for this data frame.
# (0.5 marks)
# 4. Create a correla􀆟on table for the data frame and comment about what kind of correla􀆟on is there between danceability and
# energy (0.5 marks)
# 5. Display first five rows for this data frame.(0.5 marks)
# 6. Display last five rows for this data frame. (0.5 marks)
# 7. Display the rows between 15 to 39 for this data frame. (0.5 marks)
# 8. Display the data only for last five rows and last five columns for this data frame. (0.5 marks)
# 9. Display the shape for this data frame. (0.5 marks)
# 10. Display the sum of NULL values for all the columns. (0.5 marks)
# 11. Remove first 3 columns from this Data Frame. (0.5 marks)
# 12. Remove first 10 rows from this Data Frame. (0.5 marks)
# 13. A􀅌er removing first 3 columns and first 10 rows from this data frame find outliers for the column popularity. (1 marks)
# 14. A􀅌er removing first 3 columns and first 10 rows from this data frame remove outliers for the column energy then display
# the data frame. (1 marks)
# 15. Display cross tabula􀆟on between 􀆟me_signature and track_genre for actual Data Frame. (1 marks)

# %%
import pandas as pd
#1..
df=pd.read_csv("spotify.csv")
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
#2...
x1=df.info()
x1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
# 3. Display basic sta􀆟s􀆟cs like mean, std, quar􀆟les, etc. for this data frame.
c1=df.describe()
c1
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
# 4. Create a correla􀆟on table for the data frame and comment about what kind of correla􀆟on is there between danceability and
# energy (0.5 marks)
c2=df.corr(numeric_only=True)
c2
# Out:
#                   Unnamed: 0  popularity  duration_ms  explicit  danceability  \
# Unnamed: 0          1.000000    0.032142    -0.032743 -0.054736      0.003444
# popularity          0.032142    1.000000    -0.007101  0.044082      0.035448
# duration_ms        -0.032743   -0.007101     1.000000 -0.065263     -0.073426
# explicit           -0.054736    0.044082    -0.065263  1.000000      0.122507
# danceability        0.003444    0.035448    -0.073426  0.122507      1.000000
# energy             -0.055994    0.001056     0.058523  0.096955      0.134325
# key                -0.005520   -0.003853     0.008114  0.004484      0.036469
# loudness           -0.027307    0.050423    -0.003470  0.108588      0.259077
# mode                0.005107   -0.013931    -0.035556 -0.037212     -0.069219
# speechiness        -0.084952   -0.044927    -0.062600  0.307952      0.108626
# acousticness        0.076840   -0.025472    -0.103788 -0.094403     -0.171533
# ...

# %%
print("Correlation between danceability and energy:", df['danceability'].corr(df['energy']))
# Out:
# Correlation between danceability and energy: 0.13432548346897266

# %%
# 5. Display first five rows for this data frame.(0.5 marks)
c3=df.head()
c3
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
 # 6. Display last five rows for this data frame. (0.5 marks)
c4=df.tail()
c4
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
 # 7. Display the rows between 15 to 39 for this data frame. (0.5 marks)
c5=df.loc[15:39]
c5
# Out:
#     Unnamed: 0                track_id                               artists  \
# 15          15  1KHdq8NK9QxnGjdXb55NiG                           Landon Pigg
# 16          16  6xKeQgzfjixSUld14qUezm                  Andrew Foy;Renee Foy
# 17          17  4Yo0igmcoNyat1secaH0OD                  Andrew Foy;Renee Foy
# 18          18  2qLMf6TuEC3ruGJg4SMMN6             Jason Mraz;Colbie Caillat
# 19          19  6CgNoAbFJ4Q4Id4EjtbXlC               Boyce Avenue;Bea Miller
# 20          20  3S0OXQeoh0w6AY8WQVckRW                            Jason Mraz
# 21          21  210JCw2LbYD4YIs8GiZ9iP            Boyce Avenue;Jennel Garcia
# 22          22  5TvE3pk05pyFIGdSY9j4DJ  A Great Big World;Christina Aguilera
# 23          23  0BUuuEvNa5T4lMaewyiudB                            Jason Mraz
# 24          24  3Hn3LfhrQOaKihdCibJsTs                            Jason Mraz
# 25          25  6D33wCKzWtNEgOovgeVJ7r                            Jason Mraz
# ...

# %%
# 8. Display the data only for last five rows and last five columns for this data frame. (0.5 marks)
c6=df.iloc[:-5,:-5]
c6
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113990      113990  2A4dSiJmbviL56CBupkh6C          Lucas Cervetti
# 113991      113991  0CE0Y6GM75cbrqao8EOAlW            Chris Tomlin
# 113992      113992  3FjOBB4EyIXHYUtSgrIdY9           Jesus Culture
# 113993      113993  4OkMK49i3NApR1KsAIsTf6            Chris Tomlin
# 113994      113994  4WbOUe6T0sozC7z5ZJgiAA          Lucas Cervetti
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# 9. Display the shape for this data frame. (0.5 marks)
c7=df.shape
c7
# Out:
# (114000, 21)

# %%
# 10. Display the sum of NULL values for all the columns. (0.5 marks)
c8=df.isnull().sum()
c8
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#11. Remove first 3 columns from this Data Frame. (0.5 marks)
c9=df.drop(df.columns[:3],axis=1)
c9
# Out:
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# ...

# %%
# 12. Remove first 10 rows from this Data Frame. (0.5 marks)
c10=df.iloc[10:,::]
c10.head()
# Out:
#     Unnamed: 0                track_id                   artists  \
# 10          10  4mzP5mHkRvGxdhdGdAH7EJ              Zack Tabudlo
# 11          11  5ivF4eQBqJiVL5IAE9jRyl                Jason Mraz
# 12          12  4ptDJbJl35d7gQfeNteBwp                  Dan Berk
# 13          13  0X9MxHR1rTkEHDjp95F2OO             Anna Hamilton
# 14          14  4LbWtBkN82ZRhz9jqzgrb3  Chord Overstreet;Deepend
#
#                     album_name            track_name  popularity  duration_ms  \
# 10                     Episode  Give Me Your Forever          74       244800
# 11  Love Is a Four Letter Word       I Won't Give Up          69       240165
# 12                        Solo                  Solo          52       198712
# 13                    Bad Liar              Bad Liar          62       248448
# 14             Hold On (Remix)       Hold On - Remix          56       188133
#
#     explicit  danceability  energy  ...  loudness  mode  speechiness  \
# ...

# %%
# 13. A􀅌er removing first 3 columns and first 10 rows from this data frame find outliers for the column popularity. (1 marks)
c11=df.drop(df.columns[:3],axis=1)
print("Drop columns",c11)
c12=c11.drop(df.index[:10],axis=0)
print("Drop rows",c12)
# Out:
# Drop columns                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 0                           Comedy          73       230666     False
# 1                 Ghost - Acoustic          55       149610     False
# ...

# %%
Q1=c12['popularity'].quantile(0.25)
Q3=c12['popularity'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
higher_bound=Q3+1.5*IQR
jesus=c12[(c12['popularity']<lower_bound)|(c12['popularity']>higher_bound)]
jesus['popularity']
# Out:
# 20001    100
# 81051    100
# Name: popularity, dtype: int64

# %%
cross_tab = pd.crosstab(df['time_signature'], df['track_genre'])
print(cross_tab)
# Out:
# track_genre     acoustic  afrobeat  alt-rock  alternative  ambient  anime  \
# time_signature
# 0                      0         0         1            0        3      0
# 1                      9         5         1            2       39      7
# 3                    101        52        56           64      264     63
# 4                    877       930       940          922      648    923
# 5                     13        13         2           12       46      7
#
# track_genre     black-metal  bluegrass  blues  brazil  ...  spanish  study  \
# time_signature                                         ...
# 0                         0          0      0       0  ...        0      0
# 1                        20          5      6       5  ...        2      6
# 3                       129         80     97      42  ...       55     49
# 4                       838        909    894     939  ...      937    934
# ...
