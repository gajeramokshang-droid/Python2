# %% [markdown]
# ## <font color='red'>CH5 CLASSIFICATION ALGORITM-CATEGORIAL DATA 12 MARKS</font>

# %% [markdown]
# ## <font color='blue'>MOKSHANG</font>

# %% [markdown]
# ## 1] ACCURACY=TP+TN/(TP+TN+FP+FN)

# %% [markdown]
# ## 2]  ERROR RATE=FP+FN/TP+TN+FP+FN

# %% [markdown]
# ## SENSITIVITY=TO/TP+FN

# %% [markdown]
# ##  SPACIFICITY=TN/TN+FP
