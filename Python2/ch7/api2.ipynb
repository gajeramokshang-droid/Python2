# %%
import  requests
from bs4 import BeautifulSoup

# %%
api_key='731f7ea9dc5bdd1f08687ddd11ebcdb0'
city=input("Enter the name of your city:")
website=f'http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}'
result=requests.get(website)
coordi=result.json()
coordi
# Out:
# Enter the name of your city: katargam
# [{'name': 'Katargam Daravaja',
#   'lat': 21.2102696,
#   'lon': 72.8268304,
#   'country': 'IN',
#   'state': 'Gujarat'}]

# %%
latitude=coordi[0]['lat']
print(latitude)
# Out:
# 21.2102696

# %%
longitude=coordi[0]['lon']
longitude
# Out:
# 72.8268304

# %%
url=f'https://api.openweathermap.org/data/2.5/weather?lat={latitude}&lon={longitude}&units=metric&appid={api_key}'
result=requests.get(url)
coor=result.json()
coor
# Out:
# {'coord': {'lon': 72.8268, 'lat': 21.2103},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 33.69,
#   'feels_like': 37.4,
#   'temp_min': 33.69,
#   'temp_max': 33.69,
#   'pressure': 1006,
#   'humidity': 49,
#   'sea_level': 1006,
#   'grnd_level': 1004},
#  'visibility': 10000,
#  'wind': {'speed': 5.63, 'deg': 222, 'gust': 5.84},
#  'clouds': {'all': 11},
#  'dt': 1779452294,
#  'sys': {'country': 'IN', 'sunrise': 1779409714, 'sunset': 1779457344},
#  'timezone': 19800,
#  'id': 1253640,
#  'name': 'Utrān',
#  'cod': 200}

# %%
coor['weather'][0]['main']
# Out:
# 'Clouds'

# %%
coor['wind']
# Out:
# {'speed': 5.63, 'deg': 222, 'gust': 5.84}
