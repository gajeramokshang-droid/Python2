# %%
# Using the Open Weather Map API, find the wind_speed of ahmedabad

# %%
import requests
from bs4 import BeautifulSoup
api_key='76bbb98de15cb7d16f0a7b4644071b52'
lat = 23.0225
lon = 72.5714 
website=f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=metric&appid={api_key}'
result=requests.get(website)
data=result.json()
data['wind']['speed']
# Out:
# 5.14
