# %%
import requests,json
from bs4 import BeautifulSoup

# %%
api_key = "76bbb98de15cb7d16f0a7b4644071b52"
city = input("Enter name of city: ")
website = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}"
result=requests.get(website)
coordinates=result.json()
lat=coordinates[0]["lat"]
lon=coordinates[0]['lon']
longitude
# Out:
# Enter name of city:  surt
# 3.2553

# %%
latitude
# Out:
# 45.9383

# %%
url=f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&units=metric&appid={api_key}'
response=requests.get(url)
if response.status_code==200:
    data=response.json()
    print(data)
else:
    print(response.status_code)
# Out:
# {'coord': {'lon': 3.2553, 'lat': 45.9383}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 13.08, 'feels_like': 12.74, 'temp_min': 13.08, 'temp_max': 13.08, 'pressure': 1026, 'humidity': 88, 'sea_level': 1026, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 1.54, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1779424895, 'sys': {'type': 1, 'id': 6496, 'country': 'FR', 'sunrise': 1779422880, 'sunset': 1779477574}, 'timezone': 7200, 'id': 2979447, 'name': 'Saint-Ignat', 'cod': 200}

# %%
data['weather'][0]['description']
# Out:
# 'clear sky'

# %%
data['main']['temp']
# Out:
# 13.08

# %%
data['wind']['speed']
# Out:
# 1.54

# %%
data['visibility']
# Out:
# 10000

# %%
# AIR POLLUTION API

url=f'http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}'
response=requests.get(url)
if response.status_code==200:
    data=response.json()
    print(data)
else:
    print(response.status_code)
# Out:
# {'coord': {'lon': 3.2553, 'lat': 45.9383}, 'list': [{'main': {'aqi': 1}, 'components': {'co': 74.75, 'no': 0.02, 'no2': 2.34, 'o3': 28.97, 'so2': 0.07, 'pm2_5': 1.52, 'pm10': 2.13, 'nh3': 27.41}, 'dt': 1779424694}]}

# %%
coordinates['list'][0]['main']['aqi']

# %%
if(coordinates['list'][0]['main']['aqi']==1):
    print('clear')
elif(coordinates['list'][0]['main']['aqi']<=5):
    print('mid')
else:
    print("High")
# Out:
# mid

# %%
#
